# %%
import os
import json
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
isGenerateReport = False

# %%
dataset_tables = {}

for file in os.listdir("./original-dataset"):
    df = pd.read_csv(f"./original-dataset/{file}")
    fileName = file[:-4]
    dataset_tables[fileName] = df
    
    if isGenerateReport:
        title = "{title} Report".format(title=fileName.replace("-", " ").title())
        ProfileReport(df, title=title, explorative=True).to_file(f"./profile-reports/{fileName}-report.html")

# %%
dataset_tables
# Out:
# {'genome-scores':           movieId  tagId  relevance
#  0               1      1    0.02500
#  1               1      2    0.02500
#  2               1      3    0.05775
#  3               1      4    0.09675
#  4               1      5    0.14675
#  ...           ...    ...        ...
#  11709763   131170   1124    0.58775
#  11709764   131170   1125    0.01075
#  11709765   131170   1126    0.01575
#  11709766   131170   1127    0.11450
#  11709767   131170   1128    0.02175
#
#  [11709768 rows x 3 columns],
#  'genome-tags':       tagId           tag
#  0         1           007
#  1         2  007 (series)
#  2         3  18th century
#  3         4         1920s
#  4         5         1930s
#  ...     ...           ...
#  1123   1124       writing
#  1124   1125         wuxia
#  1125   1126          wwii
#  1126   1127        zombie
#  1127   1128       zombies
#
#  [1128 rows x 2 columns],
#  'links':        movieId   imdbId    tmdbId
#  0            1   114709     862.0
#  1            2   113497    8844.0
#  2            3   113228   15602.0
#  3            4   114885   31357.0
#  4            5   113041   11862.0
#  ...        ...      ...       ...
#  27273   131254   466713    4436.0
#  27274   131256   277703    9274.0
#  27275   131258  3485166  285213.0
#  27276   131260   249110   32099.0
#  27277   131262  1724965  286971.0
#
#  [27278 rows x 3 columns],
#  'movies':        movieId                               title  \
#  0            1                    Toy Story (1995)
#  1            2                      Jumanji (1995)
#  2            3             Grumpier Old Men (1995)
#  3            4            Waiting to Exhale (1995)
#  4            5  Father of the Bride Part II (1995)
#  ...        ...                                 ...
#  27273   131254        Kein Bund für's Leben (2007)
#  27274   131256       Feuer, Eis & Dosenbier (2002)
#  27275   131258                  The Pirates (2014)
#  27276   131260                 Rentun Ruusu (2001)
#  27277   131262                    Innocence (2014)
#
#                                              genres
#  0      Adventure|Animation|Children|Comedy|Fantasy
#  1                       Adventure|Children|Fantasy
#  2                                   Comedy|Romance
#  3                             Comedy|Drama|Romance
#  4                                           Comedy
#  ...                                            ...
#  27273                                       Comedy
#  27274                                       Comedy
#  27275                                    Adventure
#  27276                           (no genres listed)
#  27277                     Adventure|Fantasy|Horror
#
#  [27278 rows x 3 columns],
#  'ratings':           userId  movieId  rating   timestamp
#  0              1        2     3.5  1112486027
#  1              1       29     3.5  1112484676
#  2              1       32     3.5  1112484819
#  3              1       47     3.5  1112484727
#  4              1       50     3.5  1112484580
#  ...          ...      ...     ...         ...
#  20000258  138493    68954     4.5  1258126920
#  20000259  138493    69526     4.5  1259865108
#  20000260  138493    69644     3.0  1260209457
#  20000261  138493    70286     5.0  1258126944
#  20000262  138493    71619     2.5  1255811136
#
#  [20000263 rows x 4 columns],
#  'tags':         userId  movieId            tag   timestamp
#  0           18     4141    Mark Waters  1240597180
#  1           65      208      dark hero  1368150078
#  2           65      353      dark hero  1368150079
#  3           65      521  noir thriller  1368149983
#  4           65      592      dark hero  1368150078
#  ...        ...      ...            ...         ...
#  465559  138446    55999        dragged  1358983772
#  465560  138446    55999  Jason Bateman  1358983778
#  465561  138446    55999         quirky  1358983778
#  465562  138446    55999            sad  1358983772
#  465563  138472      923  rise to power  1194037967
#
#  [465564 rows x 4 columns]}

# %%
for tableName in dataset_tables:
    print(f"Number of rows in {tableName}: {len(dataset_tables[tableName].index)}")
# Out:
# Number of rows in genome-scores: 11709768
# Number of rows in genome-tags: 1128
# Number of rows in links: 27278
# Number of rows in movies: 27278
# Number of rows in ratings: 20000263
# Number of rows in tags: 465564

# %%
def getMissingKeys(primaryTable, foreignTable, keyName, isShowProgress=False):
    foreignKeys = set(foreignTable[keyName].to_list())
    primaryKeys = set(primaryTable[keyName].to_list())
    
    missingKeys = []
    numMissingKeys = 0
    
    for i, primaryKey in enumerate(primaryKeys):
        if not primaryKey in foreignKeys:
            missingKeys.append(primaryKey)
            numMissingKeys += 1
        
        if isShowProgress:
            print(i)
    
    return numMissingKeys, missingKeys

# %%
getMissingKeys(dataset_tables["movies"], dataset_tables["ratings"], "movieId")
# Out:
# (534,
#  [26018,
#   26580,
#   27249,
#   27396,
#   31797,
#   32773,
#   33019,
#   33229,
#   33573,
#   45994,
#   63280,
#   65078,
#   66622,
#   69332,
#   69565,
#   69864,
#   72681,
#   72897,
#   72908,
#   77451,
#   78713,
#   79363,
#   80226,
#   80592,
#   80787,
#   80827,
#   84291,
#   85476,
#   86314,
#   86372,
#   86949,
#   87266,
#   87466,
#   88471,
#   88833,
#   89100,
#   89135,
#   89215,
#   89341,
#   89482,
#   89806,
#   90035,
#   90116,
#   90493,
#   92268,
#   92516,
#   92845,
#   92925,
#   93002,
#   94076,
#   94435,
#   94725,
#   94808,
#   96086,
#   96176,
#   96193,
#   96275,
#   96576,
#   96598,
#   98389,
#   98398,
#   98452,
#   98583,
#   98924,
#   99020,
#   99515,
#   99562,
#   99717,
#   100463,
#   100577,
#   101216,
#   101224,
#   101237,
#   101407,
#   101472,
#   101505,
#   102156,
#   102327,
#   102417,
#   102821,
#   102823,
#   103177,
#   103472,
#   103641,
#   104095,
#   104748,
#   104750,
#   105111,
#   105279,
#   105542,
#   105792,
#   105796,
#   105961,
#   105963,
#   106028,
#   106188,
#   106245,
#   106268,
#   106423,
#   106483,
#   106521,
#   106859,
#   107226,
#   107289,
#   107640,
#   108046,
#   108125,
#   108422,
#   108816,
#   108844,
#   108846,
#   109021,
#   109231,
#   109287,
#   109319,
#   109357,
#   109392,
#   109468,
#   109647,
#   109767,
#   110036,
#   110108,
#   110136,
#   110155,
#   110242,
#   110354,
#   110368,
#   110370,
#   110377,
#   110399,
#   110428,
#   110493,
#   110531,
#   110539,
#   110696,
#   110761,
#   110820,
#   110916,
#   110973,
#   111318,
#   111358,
#   111519,
#   111667,
#   111874,
#   111901,
#   111946,
#   111997,
#   112023,
#   112081,
#   112116,
#   112206,
#   112271,
#   112353,
#   112419,
#   112432,
#   112477,
#   112508,
#   112510,
#   112546,
#   112591,
#   112648,
#   112751,
#   112880,
#   113145,
#   113230,
#   113290,
#   113323,
#   113614,
#   113670,
#   113686,
#   113755,
#   113872,
#   113949,
#   114095,
#   114128,
#   114382,
#   114417,
#   114620,
#   114685,
#   114687,
#   114777,
#   114805,
#   114893,
#   114895,
#   114963,
#   115027,
#   115038,
#   115137,
#   115277,
#   115376,
#   115423,
#   115545,
#   115556,
#   115607,
#   115690,
#   115756,
#   115793,
#   115795,
#   115797,
#   115801,
#   115836,
#   115864,
#   115907,
#   115963,
#   115965,
#   115991,
#   116118,
#   116205,
#   116235,
#   116253,
#   116289,
#   116321,
#   116341,
#   116343,
#   116351,
#   116403,
#   116423,
#   116427,
#   116429,
#   116439,
#   116449,
#   116457,
#   116471,
#   116473,
#   116507,
#   116517,
#   116521,
#   116543,
#   116555,
#   116557,
#   116570,
#   116590,
#   116672,
#   116698,
#   116702,
#   116724,
#   116732,
#   116740,
#   116742,
#   116746,
#   116835,
#   116845,
#   116863,
#   116879,
#   116881,
#   116885,
#   116935,
#   116975,
#   117103,
#   117111,
#   117125,
#   117127,
#   117152,
#   117164,
#   117166,
#   117168,
#   117170,
#   117178,
#   117186,
#   117188,
#   117198,
#   117324,
#   117352,
#   117438,
#   117440,
#   117474,
#   117484,
#   117596,
#   117610,
#   117626,
#   117634,
#   117640,
#   117666,
#   117672,
#   117682,
#   117686,
#   117690,
#   117692,
#   117696,
#   117702,
#   117704,
#   117736,
#   117738,
#   117746,
#   117748,
#   117838,
#   117901,
#   117956,
#   117962,
#   117964,
#   117977,
#   117979,
#   117981,
#   118008,
#   118017,
#   118025,
#   118087,
#   118089,
#   118091,
#   118115,
#   118183,
#   118230,
#   118514,
#   118520,
#   118722,
#   118752,
#   118754,
#   118756,
#   118786,
#   118788,
#   118790,
#   118806,
#   118812,
#   118826,
#   118832,
#   118842,
#   118846,
#   118894,
#   118908,
#   118920,
#   119316,
#   119456,
#   119585,
#   119589,
#   119595,
#   119603,
#   119605,
#   119621,
#   119625,
#   119661,
#   119754,
#   119758,
#   119760,
#   119762,
#   119766,
#   119858,
#   119929,
#   120096,
#   120200,
#   120208,
#   120234,
#   120258,
#   120286,
#   120380,
#   120414,
#   120492,
#   120516,
#   120518,
#   120614,
#   120618,
#   120751,
#   120785,
#   120843,
#   121003,
#   121011,
#   121047,
#   121053,
#   121055,
#   121057,
#   121059,
#   121061,
#   121101,
#   121119,
#   121148,
#   121169,
#   121221,
#   121233,
#   121237,
#   121239,
#   121247,
#   121249,
#   121279,
#   121288,
#   121290,
#   121296,
#   121320,
#   121376,
#   121390,
#   121415,
#   121426,
#   121432,
#   121451,
#   121604,
#   121612,
#   121614,
#   121618,
#   121632,
#   121634,
#   121644,
#   121650,
#   121677,
#   121693,
#   121703,
#   121715,
#   121727,
#   121729,
#   121741,
#   121763,
#   121767,
#   121777,
#   121815,
#   121821,
#   121825,
#   121841,
#   121845,
#   121849,
#   121857,
#   121873,
#   121875,
#   121877,
#   121889,
#   121917,
#   121929,
#   121931,
#   121965,
#   121973,
#   121993,
#   121999,
#   122011,
#   122015,
#   122045,
#   122048,
#   122058,
#   122062,
#   122129,
#   122151,
#   122155,
#   122157,
#   122159,
#   122199,
#   122210,
#   122218,
#   122220,
#   122240,
#   122266,
#   122272,
#   122282,
#   122294,
#   122302,
#   122306,
#   122325,
#   122359,
#   122371,
#   122373,
#   122393,
#   122397,
#   122409,
#   122876,
#   122878,
#   122954,
#   123215,
#   123252,
#   123337,
#   123431,
#   124462,
#   124611,
#   125095,
#   125483,
#   125555,
#   125569,
#   125601,
#   125603,
#   125605,
#   125607,
#   125609,
#   125623,
#   126116,
#   127108,
#   127114,
#   127122,
#   127124,
#   127130,
#   127132,
#   127138,
#   127140,
#   127142,
#   127144,
#   127146,
#   127154,
#   127156,
#   127160,
#   127162,
#   127164,
#   127170,
#   127176,
#   127178,
#   127184,
#   127190,
#   127204,
#   127208,
#   127214,
#   127311,
#   127331,
#   127455,
#   127498,
#   127567,
#   127569,
#   127573,
#   127575,
#   127579,
#   127581,
#   127583,
#   127606,
#   127608,
#   127614,
#   127640,
#   127644,
#   127667,
#   127669,
#   127681,
#   127843,
#   127845,
#   127851,
#   128085,
#   128247,
#   128277,
#   128279,
#   128283,
#   128439,
#   128684,
#   128864,
#   128866,
#   128868,
#   128870,
#   128872,
#   128874,
#   128876,
#   128878,
#   128880,
#   128886,
#   129201,
#   129443,
#   129820,
#   130040])

# %%
movieForeignTables = ["links", "ratings", "tags", "genome-scores"]
genomeTagForeignTables = ["genome-scores"]

movieForeignKeys = {
    "missingForeignKeys": {},
    "nonExistentKeys": {}
}

genomeTagForeignKeys = {
    "missingForeignKeys": {},
    "nonExistentKeys": {}
}

print("Movies:")
for tableName in movieForeignTables:
    numMissingForeignKeys, missingForeignKeys = getMissingKeys(dataset_tables["movies"], dataset_tables[tableName], "movieId")
    numNonExistentPrimaryKeys, nonExistentPrimaryKeys = getMissingKeys(dataset_tables[tableName], dataset_tables["movies"], "movieId")
    
    movieForeignKeys["missingForeignKeys"][tableName] = missingForeignKeys
    movieForeignKeys["nonExistentKeys"][tableName] = nonExistentPrimaryKeys
    
    print(f"{tableName} has {numMissingForeignKeys} missing foreign keys | {numNonExistentPrimaryKeys} non-existent keys")

print("\nGenome Tags:")
for tableName in genomeTagForeignTables:
    numMissingForeignKeys, missingForeignKeys = getMissingKeys(dataset_tables["genome-tags"], dataset_tables[tableName], "tagId")
    numNonExistentPrimaryKeys, nonExistentPrimaryKeys = getMissingKeys(dataset_tables[tableName], dataset_tables["genome-tags"], "tagId")
    
    genomeTagForeignKeys["missingForeignKeys"][tableName] = missingForeignKeys
    genomeTagForeignKeys["nonExistentKeys"][tableName] = nonExistentPrimaryKeys
    
    print(f"{tableName} has {numMissingForeignKeys} missing foreign keys | {numNonExistentPrimaryKeys} non-existent keys")
    
with open("movie-missing-foreign-keys.json", "w") as outfile:
    json.dump(movieForeignKeys, outfile)
    
with open("genome-tag-foreign-keys.json", "w") as outfile:
    json.dump(genomeTagForeignKeys, outfile)
# Out:
# Movies:
# links has 0 missing foreign keys | 0 non-existent keys
# ratings has 534 missing foreign keys | 0 non-existent keys
# tags has 7733 missing foreign keys | 0 non-existent keys
# genome-scores has 16897 missing foreign keys | 0 non-existent keys
#
# Genome Tags:
# genome-scores has 0 missing foreign keys | 0 non-existent keys

# %%
isGenerateRelevantTags = False

# %%
movie_to_tag_relevance = {} # key is movieId, values are a list of tagIds

if isGenerateRelevantTags:
    movie_ids = sorted(list(set(dataset_tables["genome-scores"]["movieId"].tolist())))
    print("Number of movie ids:", len(movie_ids))
    tags_scores_matrix = np.array(np.array_split(dataset_tables["genome-scores"]["relevance"].values.flatten(), len(movie_ids)))
    print("Tag scores matrix shape:", tags_scores_matrix.shape)

    tag_id_to_name = dataset_tables["genome-tags"].set_index("tagId").T.to_dict("list")

    for i, movie_id in enumerate(movie_ids):
        movie_to_tag_relevance[movie_id] = [tag_id_to_name[x+1][0] for x in np.argpartition(tags_scores_matrix[i], -4)[-4:].tolist()]

    with open("movie_to_relevant_tags.json", "w") as outfile:
        json.dump(movie_to_tag_relevance, outfile)
else:
    with open('movie_to_relevant_tags.json', 'r') as fp:
        movie_to_tag_relevance = json.load(fp)

# %%
movie_to_tag_relevance
# Out:
# {'1': ['kids and family', 'pixar animation', 'computer animation', 'toys'],
#  '2': ['kids', 'adventure', 'jungle', 'children'],
#  '3': ['comedy', 'sequels', 'good sequel', 'sequel'],
#  '4': ['romantic', 'girlie movie', 'chick flick', 'women'],
#  '5': ['sequel', 'sequels', 'good sequel', 'father daughter relationship'],
#  '6': ['bank robbery', 'gunfight', 'heist', 'crime'],
#  '7': ['romance', 'romantic comedy', 'romantic', 'remake'],
#  '8': ['childhood', 'unlikely friendships', 'based on a book', 'adventure'],
#  '9': ['video game adaptation', 'lone hero', 'good action', 'action'],
#  '10': ['franchise', 'bond', '007 (series)', '007'],
#  '11': ['world politics', 'political', 'politics', 'president'],
#  '12': ['goofy', 'comedy', 'spoof', 'parody'],
#  '13': ['dog', 'animated', 'animation', 'talking animals'],
#  '14': ['politics', 'biographical', 'world politics', 'president'],
#  '15': ['action', 'swashbuckler', 'treasure hunt', 'pirates'],
#  '16': ['gangster', 'mob', 'organized crime', 'mafia'],
#  '17': ['period piece', '18th century', 'costume drama', 'adapted from:book'],
#  '18': ['tarantino', 'hotel', 'storytelling', 'off-beat comedy'],
#  '19': ['dumb', 'comedy', 'silly fun', 'goofy'],
#  '20': ['fast paced', 'action packed', 'action', 'good action'],
#  '21': ['gangster', 'gangsters', 'great movie', 'mob'],
#  '22': ['suspense', 'suspenseful', 'serial killer', 'detective'],
#  '23': ['action', 'assassins', 'hit men', 'assassin'],
#  '24': ['poignant', 'emotional', 'humanity', 'touching'],
#  '25': ['love', 'melancholic', 'drinking', 'loneliness'],
#  '26': ['adaptation', 'betrayal', 'based on a play', 'shakespeare'],
#  '27': ['unlikely friendships', 'friendship', 'coming of age', 'girlie movie'],
#  '28': ['adaptation', 'period piece', 'jane austen', 'adapted from:book'],
#  '29': ['surreal', 'visual', 'visually stunning', 'dark fantasy'],
#  '30': ['gangsters', 'visual', 'beautifully filmed', 'cinematography'],
#  '31': ['based on true story', 'inspirational', 'high school', 'teacher'],
#  '32': ['science fiction', 'time travel', 'time loop', 'future'],
#  '33': ['pg-13', 'unusual plot structure', 'original', '70mm'],
#  '34': ['pigs', 'animal movie', 'talking animals', 'animals'],
#  '35': ['love story', 'intimate', 'love', 'relationships'],
#  '36': ['oscar (best actress)', 'crime', 'death penalty', 'death'],
#  '37': ['technology', 'visual', 'storytelling', 'new york city'],
#  '38': ['girlie movie', 'switching places', 'cute!', 'cute'],
#  '39': ['teenager', 'girlie movie', 'teen movie', 'teen'],
#  '40': ['beautiful scenery', 'africa', 'based on a book', 'south africa'],
#  '41': ['robert downey jr', '1930s', 'based on a play', 'shakespeare'],
#  '42': ['bank robbery', 'crime', 'violence', 'heist'],
#  '43': ['england', 'historical', 'robert downey jr', 'period piece'],
#  '44': ['video game',
#   'martial arts',
#   'based on a video game',
#   'video game adaptation'],
#  '45': ['black comedy', 'dark comedy', 'obsession', 'dark humor'],
#  '46': ['adultery', 'love', 'chick flick', 'women'],
#  '47': ['powerful ending',
#   'police investigation',
#   'serial killer',
#   'detective'],
#  '48': ['indians', 'native americans', 'disney animated feature', 'animation'],
#  '49': ['nudity (topless - notable)', 'love', 'love story', 'lesbian'],
#  '50': ['twists & turns',
#   'plot twist',
#   'oscar (best supporting actor)',
#   'surprise ending'],
#  '52': ['oscar (best actor)',
#   'adoption',
#   'oscar (best actress)',
#   'oscar (best supporting actress)'],
#  '53': ['greed', 'giant robots', 'criterion', 'poverty'],
#  '54': ['underdog', 'football', 'kids', 'sports'],
#  '55': ['relationships', 'good soundtrack', 'sisters', 'musicians'],
#  '56': ['predictable', 'kids and family', 'original', 'kids'],
#  '57': ['holiday',
#   'off-beat comedy',
#   'robert downey jr',
#   'dysfunctional family'],
#  '58': ['love story',
#   'melancholic',
#   'beautiful scenery',
#   'beautifully filmed'],
#  '59': ['original', 'hitchcock', 'enigmatic', 'criterion'],
#  '60': ['based on a book', 'magic', 'indians', 'based on book'],
#  '61': ['vengeance', 'vigilantism', 'vigilante', 'revenge'],
#  '62': ['musicians', 'teacher', 'mentor', 'music'],
#  '63': ['comedy', 'funniest movies', 'parody', 'spoof'],
#  '64': ['original', 'sarcasm', 'romantic comedy', 'life philosophy'],
#  '65': ['dumb but funny', 'goofy', 'stupid', 'stupidity'],
#  '66': ['bad acting', 'virtual reality', 'horrible', 'special effects'],
#  '67': ['dreams', 'life & death', 'homeless', 'coming of age'],
#  '68': ['spanish', 'cheating', 'adultery', 'lesbian'],
#  '69': ['marijuana', 'funny', 'comedy', 'weed'],
#  '70': ['bloody', 'vampire', 'vampires', 'splatter'],
#  '71': ['action packed', 'bad plot', 'good action', 'action'],
#  '72': ['criterion', 'college', 'dialogue driven', 'dialogue'],
#  '73': ['jews', 'beautifully filmed', 'world war ii', 'adapted from:book'],
#  '74': ['romantic comedy', 'chick flick', 'love story', 'romantic'],
#  '75': ['original', 'childhood', 'bullying', 'arnold'],
#  '76': ['robots', 'futuristic', 'scifi', 'sci-fi'],
#  '77': ['artist', 'musicians', 'music', 'documentary'],
#  '78': ['death', 'guilt', 'redemption', 'vengeance'],
#  '79': ['murder', 'tom clancy', 'thriller', 'mafia'],
#  '80': ['money', 'childhood', 'children', 'iran'],
#  '81': ['gangster', 'gangsters', 'organized crime', 'crime gone awry'],
#  '82': ['relationships',
#   'intellectual',
#   'oscar (best foreign language film)',
#   'women'],
#  '83': ['holocaust', 'race issues', 'segregation', 'visually appealing'],
#  '84': ['relationships', 'family', 'unusual plot structure', 'original'],
#  '85': ['19th century', 'period piece', 'male nudity', 'secrets'],
#  '86': ['friendship', 'based on true story', 'mentor', 'coming of age'],
#  '87': ['family', 'kids', 'single father', 'kids and family'],
#  '88': ['very funny', 'saturday night live', 'comedy', 'funny'],
#  '89': ['tense', 'suspenseful', 'conspiracy', 'suspense'],
#  '90': ['beautifully filmed', 'original', 'author:neil gaiman', 'slavery'],
#  '92': ['story', 'adapted from:book', 'original', 'irish accent'],
#  '93': ['comedy', 'horror', 'vampire', 'vampires'],
#  '94': ['good soundtrack', 'ensemble cast', 'small town', 'relationships'],
#  '95': ['explosions', 'good action', 'action', 'action packed'],
#  '96': ['love', 'witty', 'ensemble cast', 'shakespeare'],
#  '97': ['paris', 'powerful ending', 'social commentary', 'criterion'],
#  '98': ['crime', 'cult film', 'anti-hero', 'shopping'],
#  '99': ['documentary', 'marijuana', 'prostitution', 'pornography'],
#  '100': ['conspiracy', 'corruption', 'political', 'politics'],
#  '101': ['humorous', 'off-beat comedy', 'quirky', 'heist'],
#  '102': ['original', 'funny', 'comedy', 'horrible'],
#  '103': ['surprise ending', 'twists & turns', 'murder mystery', 'thriller'],
#  '104': ['sports', 'goofy', 'comedy', 'golf'],
#  '105': ['romantic', 'romance', 'bittersweet', 'love story'],
#  '106': ['criterion',
#   'oscar (best foreign language film)',
#   'german',
#   'germany'],
#  '107': ['pirates', 'treasure', 'treasure hunt', 'muppets'],
#  '108': ['documentary', 'hip hop', 'fashion', 'grindhouse'],
#  '110': ['oscar (best directing)',
#   'history',
#   'oscar (best picture)',
#   'historical'],
#  '111': ['imdb top 250', 'golden palm', 'masterpiece', 'loneliness'],
#  '112': ['hong kong', 'kung fu', 'martial arts', 'fight scenes'],
#  '113': ['guilt', 'drama', 'lawyer', 'family drama'],
#  '114': ['visually appealing', 'story', 'unusual plot structure', 'mining'],
#  '116': ['world war ii', 'holocaust', 'jews', 'anti-semitism'],
#  '117': ['humorous', 'murder', 'black comedy', 'true story'],
#  '118': ['good soundtrack', 'romantic comedy', 'relationships', 'romantic'],
#  '119': ['lawyer', 'gangsters', 'good', 'original'],
#  '120': ['silly', 'life philosophy', 'racing', 'cute'],
#  '121': ['pornography', 'corruption', 'child abuse', 'disturbing'],
#  '122': ['nudity (topless - brief)', 'hilarious', 'comedy', 'funny'],
#  '123': ['wuxia', 'loneliness', 'melancholic', 'love'],
#  '125': ['comedy', 'hilarious', 'ensemble cast', 'adoption'],
#  '126': ['fantasy world', 'horrible', 'original', 'fantasy'],
#  '128': ['documentary', 'mental illness', 'drugs', 'homeless'],
#  '129': ['obsession', 'romance', 'romantic', 'nudity (topless - notable)'],
#  '131': ['irish', 'based on true story', 'ireland', 'irish accent'],
#  '132': ['nudity (rear)', 'erotic', 'sexual', 'murder mystery'],
#  '135': ['big budget', 'comedy', 'fun movie', 'submarine'],
#  '136': ['pornography', 'women', 'criterion', 'documentary'],
#  '137': ['finnish', 'documentary', 'life philosophy', 'gay'],
#  '138': ['book', 'books', 'based on book', 'based on a book'],
#  '140': ['romance', 'romantic comedy', 'romantic', 'love story'],
#  '141': ['homosexuality', 'gay character', 'gay', 'cross dressing'],
#  '144': ['dialogue driven', 'independent film', 'relationships', 'irish'],
#  '145': ['buddy movie', 'action packed', 'good action', 'action'],
#  '146': ['family', 'adventure', 'cute', 'kids'],
#  '147': ['addiction', 'drugs', 'drug abuse', 'drug addiction'],
#  '148': ['weird', 'loneliness', 'original', 'nudity (topless - notable)'],
#  '149': ['hit men', 'deadpan', 'quirky', 'amnesia'],
#  '150': ['space', 'space program', 'astronauts', 'nasa'],
#  '151': ['sword fighting', '18th century', 'sword fight', 'scotland'],
#  '152': ['goth', 'addiction', 'vampires', 'vampire'],
#  '153': ['vigilante', 'franchise', 'batman', 'super-hero'],
#  '154': ['surreal', 'obsession', 'sexual', 'enigmatic'],
#  '155': ['jungle', 'politics', 'sacrifice', 'world politics'],
#  '156': ['relationships',
#   'independent film',
#   'new york city',
#   'highly quotable'],
#  '157': ['sarcasm', 'canada', 'politics', 'satire'],
#  '158': ['family', 'childhood', 'children', 'ghosts'],
#  '159': ['corruption', 'good soundtrack', 'crime', 'drugs'],
#  '160': ['adapted from:book', 'based on a book', 'jungle', 'adventure'],
#  '161': ['weapons', 'submarine', 'tom clancy', 'tense'],
#  '162': ['documentary', 'artistic', 'artist', 'obsession'],
#  '163': ['gunfight', 'violence', 'action', 'stylish'],
#  '164': ['los angeles', 'based on book', 'twists & turns', 'based on a book'],
#  '165': ['lone hero', 'vengeance', 'action', 'action packed'],
#  '166': ['sexual', 'splatter', 'surreal', 'cult film'],
#  '167': ['pornography', 'wartime', 'visually appealing', 'beautifully filmed'],
#  '168': ['romance', 'king arthur', 'medieval', 'love story'],
#  '169': ['original', 'family', 'sequels', 'adventure'],
#  '170': ['cyberpunk', 'geeks', 'hackers', 'hacking'],
#  '171': ['queer', 'aids', 'gay', 'gay character'],
#  '172': ['futuristic', 'future', 'dystopic future', 'cyberpunk'],
#  '173': ['futuristic',
#   'adapted from:comic',
#   'dystopic future',
#   'based on a comic'],
#  '174': ["so bad it's funny", 'very funny', 'funny', 'comedy'],
#  '175': ['golden palm', 'teen', 'drugs', 'pornography'],
#  '176': ['low budget', 'dreams', 'indie', 'independent film'],
#  '177': ['splatter', 'horror', 'cult', 'dark fantasy'],
#  '178': ['gay', 'loneliness', 'gay character', 'relationships'],
#  '179': ['love story', 'love', 'romance', 'awesome soundtrack'],
#  '180': ['new jersey', 'comedy', 'jay and silent bob', 'view askew'],
#  '181': ['mentor', 'original', 'based on a tv show', 'ninja'],
#  '182': ['women', 'life philosophy', 'chick flick', 'relationships'],
#  '183': ['suspense', 'suspenseful', 'tense', 'thriller'],
#  '184': ['pornography', 'dysfunctional family', 'original', 'vampire'],
#  '185': ['technology', 'conspiracy', 'hacking', 'internet'],
#  '186': ['pregnancy', 'chick flick', 'romantic comedy', 'comedy'],
#  '187': ['life philosophy', 'goofy', 'fun movie', 'indie'],
#  '188': ['christianity', 'devil', 'religion', 'god'],
#  '189': ['twists & turns', 'fantasy', 'hit men', 'original'],
#  '190': ['loneliness', 'enigmatic', 'environment', 'criterion'],
#  '191': ['book', 'literature', 'based on book', 'based on a book'],
#  '192': ['original', 'hip hop', 'spelling bee', 'documentary'],
#  '193': ['erotic',
#   'strippers',
#   'nudity (topless - brief)',
#   'nudity (topless)'],
#  '194': ['ensemble cast',
#   'storytelling',
#   'independent film',
#   'oscar (best supporting actor)'],
#  '195': ['cheating', 'women', 'adultery', 'infidelity'],
#  '196': ['alien invasion', 'sci-fi', 'alien', 'aliens'],
#  '197': ['period piece', '1930s', 'oil', 'small town'],
#  '198': ['virtual reality', 'futuristic', 'cyberpunk', 'future'],
#  '199': ['melancholic', 'music', 'bittersweet', 'golden palm'],
#  '200': ['women', 'adoption', 'original', 'thriller'],
#  '201': ['feel-good', 'dog', 'sentimental', 'kids and family'],
#  '202': ['relationships', 'gay character', 'writers', 'gay'],
#  '203': ['women', 'queer', 'cross dressing', 'small town'],
#  '204': ['action packed', 'action', 'train', 'good action'],
#  '205': ['dysfunctional family', 'drama', 'coming-of-age', 'cancer'],
#  '206': ['original', 'documentary', 'fashion', 'very interesting'],
#  '207': ['chick flick', 'love story', 'romance', 'romantic'],
#  '208': ['sci-fi', 'post apocalyptic', 'post-apocalyptic', 'futuristic'],
#  '209': ['original', 'alternate history', 'race issues', 'stereotypes'],
#  '210': ['original', 'life & death', 'western', 'gunfight'],
#  '211': ['school', 'based on a play', 'life & death', 'teacher'],
#  '212': ['silly fun', 'hilarious', 'comedy', 'adventure'],
#  '213': ['russia',
#   'father daughter relationship',
#   'russian',
#   'oscar (best foreign language film)'],
#  '214': ['storytelling', 'melancholic', 'non-linear', 'criterion'],
#  '215': ['romance', 'love story', 'romantic', 'dialogue driven'],
#  '216': ['stupidity', 'funniest movies', 'comedy', 'goofy'],
#  '217': ['erotic', 'pornography', 'obsession', 'fantasy'],
#  '218': ['chick flick', 'friendship', 'unlikely friendships', 'women'],
#  '219': ['touching', 'unlikely friendships', 'coming of age', 'friendship'],
#  '220': ['goretastic', 'splatter', 'creepy', 'horror'],
#  '222': ['ireland', 'friendship', 'adapted from:book', 'irish'],
#  '223': ['dialogue driven',
#   'independent film',
#   'view askew',
#   'jay and silent bob'],
#  '224': ['psychiatry', 'romance', 'fantasy', 'romantic'],
#  '225': ['erotic', 'conspiracy', 'sexual', 'based on a book'],
#  '227': ['action packed', 'fight scenes', 'action', 'good action'],
#  '228': ['magic realism', 'dialogue', 'destiny', 'las vegas'],
#  '229': ['based on a play', 'dialogue driven', 'psychological', 'guilt'],
#  '230': ['great acting', 'secrets', 'drama', 'adapted from:book'],
#  '231': ['comedy', 'funniest movies', 'suprisingly clever', 'dumb'],
#  '232': ['single father',
#   'cooking',
#   'father daughter relationship',
#   'relationships'],
#  '233': ['enigmatic', 'art house', 'melancholic', 'obsession'],
#  '234': ['based on a book', 'male nudity', 'erotic', 'bdsm'],
#  '235': ['imdb top 250',
#   'eccentricity',
#   'biopic',
#   'oscar (best supporting actor)'],
#  '236': ['love story', 'france', 'romantic', 'romantic comedy'],
#  '237': ['romance', 'romantic', 'paris', 'romantic comedy'],
#  '238': ['wilderness', 'dog', 'dogs', 'kids and family'],
#  '239': ['animation', 'disney animated feature', 'goofy', 'cartoon'],
#  '240': ['adaptation',
#   'based on book',
#   'adapted from:book',
#   'based on a book'],
#  '241': ['talking animals', 'animals', 'dog', 'dogs'],
#  '242': ['opera', 'musical', 'mozart', '18th century'],
#  '243': ['animals', 'pigs', 'family', 'children'],
#  '244': ['childhood', 'robot', 'stop motion', 'original'],
#  '245': ['police investigation', 'corruption', 'police corruption', 'police'],
#  '246': ['criterion', 'documentary', 'sports', 'oscar (best editing)'],
#  '247': ['unlikely friendships', 'fantasy world', 'friendship', 'obsession'],
#  '248': ['hilarious', 'chase', 'family', 'comedy'],
#  '249': ['music', 'biographical', 'mozart', 'classical music'],
#  '250': ['childhood', 'fun movie', 'kids', 'camp'],
#  '251': ['sword fight', 'action', 'fight scenes', 'ninja'],
#  '252': ['love story', 'romantic', 'chick flick', 'romantic comedy'],
#  '253': ['adapted from:book', 'immortality', 'vampire', 'vampires'],
#  '254': ['history', 'revolution', 'slavery', '18th century'],
#  '255': ['hilarious', 'very funny', 'funny', 'comedy'],
#  '256': ['silly', 'pregnancy', 'comedy', 'arnold'],
#  '257': ['police investigation', 'death penalty', 'lawyer', 'lawyers'],
#  '258': ['medieval', 'kids', 'time travel', 'king arthur'],
#  '259': ['gangsters', 'original', 'crime', 'nudity (topless - brief)'],
#  '260': ['trilogy', 'scifi', 'space opera', 'sci fi'],
#  '261': ['literature', 'girlie movie', 'family bonds', 'adapted from:book'],
#  '262': ['beautifully filmed',
#   'imagination',
#   'based on a book',
#   'boarding school'],
#  '263': ['intimate', 'harsh', 'working class', 'social commentary'],
#  '264': ['psychological', 'enigmatic', 'infidelity', 'obsession'],
#  '265': ['love story', 'cooking', 'passionate', 'magic realism'],
#  '266': ['family bonds', 'love story', 'oscar (best cinematography)', 'epic'],
#  '267': ['children', 'funny', 'military', 'comedy'],
#  '268': ['violence', 'dysfunctional family', 'hit men', 'mafia'],
#  '269': ['good soundtrack', 'friendship', 'gangs', 'los angeles'],
#  '270': ['remake', 'romance', 'love story', 'romantic'],
#  '271': ['lawyers', 'lawyer', 'adoption', 'mother-son relationship'],
#  '272': ['based on a play', 'england', '18th century', 'costume drama'],
#  '273': ['based on book',
#   'mad scientist',
#   'based on a book',
#   'adapted from:book'],
#  '274': ['family', 'divorce', 'chase', 'children'],
#  '275': ['original', 'comedy', 'holiday', 'christmas'],
#  '276': ['happy ending', 'kids', 'kids and family', 'single father'],
#  '277': ['original', 'christmas', 'remake', 'holiday'],
#  '278': ['original', 'marriage', 'relationships', 'infidelity'],
#  '279': ['excellent script', 'family', 'original', 'los angeles'],
#  '280': ['based on true story', 'prison', 'lawyers', 'alcatraz'],
#  '281': ['loneliness',
#   'relationships',
#   'small town',
#   'father son relationship'],
#  '282': ['emotional', 'doctors', 'drama', 'touching'],
#  '283': ['original', 'redemption', 'new jersey', 'cars'],
#  '285': ['horror', 'original', 'dreams', 'surreal'],
#  '286': ['action', 'cyborgs', 'original', 'sequels'],
#  '287': ['dialogue', 'life philosophy', 'romance', 'original'],
#  '288': ['brutality', 'gratuitous violence', 'violent', 'violence'],
#  '289': ['destiny', 'romantic', 'robert downey jr', 'romantic comedy'],
#  '290': ['powerful ending', 'violent', 'brutality', 'violence'],
#  '291': ['sexy', 'sexual', 'erotic', 'nudity (topless - notable)'],
#  '292': ['tense', 'good', 'virus', 'military'],
#  '293': ['father daughter relationship', 'hitman', 'assassin', 'hit men'],
#  '294': ['romantic comedy', 'family', 'original', 'romantic'],
#  '295': ['love story', 'original', 'chick flick', 'romantic'],
#  '296': ['masterpiece', 'dark humor', 'gratuitous violence', 'hit men'],
#  '297': ['very interesting', 'factual', 'true story', 'history'],
#  '298': ['original', 'kung fu', 'culture clash', 'family drama'],
#  '299': ['gay', 'homosexuality', 'sexual abuse', 'catholicism'],
#  '300': ['television',
#   'oscar (best supporting actor)',
#   'corruption',
#   'reality tv'],
#  '301': ['cinematography', 'tokyo', 'hawaii', 'japan'],
#  '302': ['historical', 'history', 'france', 'french'],
#  '303': ['redemption', 'western', 'small town', 'gunfight'],
#  '304': ['family', 'touching', 'cancer', 'mentor'],
#  '305': ['satire',
#   'nudity (full frontal - notable)',
#   'ensemble cast',
#   'fashion'],
#  '306': ['trilogy', 'enigmatic', 'golden palm', 'meditative'],
#  '307': ['melancholy', 'meditative', 'reflective', 'enigmatic'],
#  '308': ['poland', 'criterion', 'trilogy', 'enigmatic'],
#  '309': ['cinematography', 'original', 'love story', 'foreign'],
#  '310': ['kids', 'family', 'adoption', 'children'],
#  '311': ['original', 'twist ending', 'grindhouse', 'classic car'],
#  '312': ['original', 'satire', 'saturday night live', 'dysfunctional family'],
#  '313': ['cartoon', 'animals', 'animated', 'animation'],
#  '314': ['storytelling', 'ireland', 'irish', 'irish accent'],
#  '315': ['vengeance', 'explosions', 'action', 'good action'],
#  '316': ['sci fi', 'science fiction', 'egypt', 'sci-fi'],
#  '317': ['childhood', 'children', 'holiday', 'christmas'],
#  '318': ['oscar (best picture)',
#   'powerful ending',
#   'prison escape',
#   'imdb top 250'],
#  '319': ['dark', 'twists & turns', 'dark humor', 'greed'],
#  '320': ['life philosophy', 'original', 'pornography', 'hitchcock'],
#  '321': ['queer', 'gay', 'homosexuality', 'gay character'],
#  '322': ['manipulation', 'powerful ending', 'workplace', 'buddy movie'],
#  '324': ['homosexuality', 'father son relationship', 'gay character', 'gay'],
#  '325': ['goofy', 'road trip', 'comedy', 'teen movie'],
#  '326': ['intimate', 'communism', 'revolution', 'china'],
#  '327': ['comic book', 'mutants', 'adapted from:comic', 'based on a comic'],
#  '328': ['awesome soundtrack', 'horror', 'demons', 'splatter'],
#  '329': ['space opera', 'star trek', 'franchise', 'space'],
#  '330': ['original', 'brutality', 'violence', 'horror'],
#  '331': ['artist', 'biopic', 'doctors', 'mental illness'],
#  '332': ['science fiction', 'sci fi', 'original', 'remake'],
#  '333': ['goofy', 'road trip', 'comedy', 'funniest movies'],
#  '334': ['dialogue', 'talky', 'based on a play', 'criterion'],
#  '335': ['film noir', 'twists & turns', 'heist', 'neo-noir'],
#  '337': ['oscar (best supporting actor)',
#   'disability',
#   'dysfunctional family',
#   'small town'],
#  '338': ['action', 'technology', 'virtual reality', 'futuristic'],
#  '339': ['sweet', 'romantic', 'chick flick', 'romantic comedy'],
#  '340': ['drama', 'war', 'innocence lost', 'sentimental'],
#  '341': ['parenthood', 'unusual plot structure', 'relationships', 'original'],
#  '342': ['dysfunctional family',
#   'unlikely friendships',
#   'friendship',
#   'australia'],
#  '343': ['adapted from:book', 'teen movie', 'books', 'based on a book'],
#  '344': ['comedy', 'dumb', 'detective', 'goofy'],
#  '345': ['australia', 'queer', 'transgender', 'cross dressing'],
#  '346': ['music business', 'musicians', 'beatles', 'rock and roll'],
#  '347': ['relationships', 'sexual', 'obsession', 'bdsm'],
#  '348': ['gangster', 'mob', 'gangsters', 'oscar (best supporting actress)'],
#  '349': ['action', 'tense', 'conspiracy', 'tom clancy'],
#  '350': ['tense', 'tom clancy', 'lawyers', 'lawyer'],
#  '351': ['children', 'race issues', 'heartwarming', 'interracial romance'],
#  '352': ['life & death', 'bittersweet', 'dysfunctional family', 'original'],
#  '353': ['based on a comic', 'adapted from:comic', 'dark hero', 'goth'],
#  '354': ['biopic', 'sports', 'biographical', 'baseball'],
#  '355': ['children', 'family', 'based on a tv show', 'cartoon'],
#  '356': ['imdb top 250', 'destiny', 'life', 'oscar (best picture)'],
#  '357': ['british', 'romantic', 'romantic comedy', 'relationships'],
#  '358': ['racism', 'stereotypes', 'segregation', 'college'],
#  '359': ['bittersweet', 'great', 'original', 'vampire human love'],
#  '360': ['predictable', 'conspiracy', 'romantic comedy', 'romantic'],
#  '361': ['romantic', 'feel-good', 'feel good movie', 'romantic comedy'],
#  '362': ['animal movie', 'adventure', 'jungle', 'animals'],
#  '363': ['german', 'documentary', 'germany', 'nazis'],
#  '364': ['cartoon', 'lions', 'animation', 'disney animated feature'],
#  '365': ['story', 'visually appealing', 'visually stunning', 'life & death'],
#  '366': ['original', 'slasher', 'horror', 'franchise'],
#  '367': ['superhero', 'super hero', 'comedy', 'goofy'],
#  '368': ['fun movie', 'comedy', 'western', 'based on a tv show'],
#  '369': ['new york city', 'biography', 'biopic', 'writers'],
#  '370': ['spoof', 'funny as hell', 'comedy', 'parody'],
#  '371': ['story', 'workplace', 'parenthood', 'journalism'],
#  '372': ['life philosophy',
#   'awesome soundtrack',
#   'good soundtrack',
#   'slackers'],
#  '373': ['crime', 'hitman', 'neo-noir', 'twists & turns'],
#  '374': ['family', 'kids', 'children', 'kids and family'],
#  '375': ['pornography', 'dysfunctional family', 'drama', 'original'],
#  '376': ['scenic', 'hostage', 'action', 'good action'],
#  '377': ['chase', 'action packed', 'good action', 'action'],
#  '378': ['love story', 'romance', 'romantic', 'romantic comedy'],
#  '379': ['action', 'future', 'futuristic', 'time travel'],
#  '380': ['chase', 'good action', 'action', 'arnold'],
#  '381': ['alcoholism', 'love', 'love story', 'drinking'],
#  '382': ['drama', 'horror', 'werewolves', 'werewolf'],
#  '383': ['biopic', 'biographical', 'gunfight', 'western'],
#  '384': ['erotic', 'pornography', 'twists & turns', 'sexy'],
#  '385': ['unusual plot structure', 'loneliness', 'homosexuality', 'gay'],
#  '386': ['original', 'reality tv', 'good soundtrack', 'cult film'],
#  '387': ['action packed', 'comedy', 'good action', 'action'],
#  '388': ['sexuality', 'coming of age', 'queer', 'gay'],
#  '389': ['greed', 'wine', 'lawyer', 'criterion'],
#  '390': ['cars', 'sexual', 'cult film', 'cult classic'],
#  '391': ['romantic', 'original', 'love story', 'unusual plot structure'],
#  '392': ['animation', 'stop-motion', 'weird', 'stop motion'],
#  '393': ['video game',
#   'adapted from:game',
#   'video game adaptation',
#   'based on a video game'],
#  '394': ['cult classic', 'violence', 'violent', 'dark humor'],
#  '397': ['demons', 'original', 'horror', 'halloween'],
#  '398': ['documentary', 'animal movie', 'animation', 'beer'],
#  '402': ['farce', 'original', 'satire', 'off-beat comedy'],
#  '405': ['sequels', 'good sequel', 'immortality', 'franchise'],
#  '406': ['original', 'independent film', 'very interesting', 'gay'],
#  '407': ['cult classic', 'weird', 'splatter', 'horror'],
#  '408': ['great', 'destiny', 'love story', 'true story'],
#  '409': ['new jersey', 'hip hop', 'basketball', 'sports'],
#  '410': ['original', 'good sequel', 'sequels', 'camp'],
#  '411': ['original', 'hilarious', 'stand-up comedy', 'funny as hell'],
#  '412': ['adapted from:book',
#   'literary adaptation',
#   'costume drama',
#   'period piece'],
#  '413': ['radio', 'awesome soundtrack', 'rock and roll', 'comedy'],
#  '414': ['mentor', 'africa', 'basketball', 'sports'],
#  '415': ['original', 'sequels', 'comedy', 'sequel'],
#  '416': ['culture clash', 'original', 'women', 'western'],
#  '417': ['talky', 'dialogue', 'cerebral', 'dialogue driven'],
#  '418': ['cerebral', 'storytelling', 'original', 'humanity'],
#  '419': ['saturday night live', 'based on a tv show', 'franchise', 'original'],
#  '420': ['sequel', 'comedy', 'good action', 'action'],
#  '421': ['beautiful scenery',
#   'beautifully filmed',
#   'amazing cinematography',
#   'horses'],
#  '422': ['thriller', 'suspenseful', 'serial killer', 'blindness'],
#  '423': ['irish', 'boston', 'action', 'irish accent'],
#  '424': ['golf', 'college', 'basketball', 'sports'],
#  '425': ['oscar',
#   'oscar (best supporting actress)',
#   'original',
#   'oscar (best actress)'],
#  '426': ['original', 'remake', 'alien', 'aliens'],
#  '427': ['erotic', 'pornography', 'obsession', 'nudity (topless - notable)'],
#  '428': ['gangster', 'mafia', 'gangsters', 'organized crime'],
#  '429': ['irreverent', 'goofy', 'off-beat comedy', 'parody'],
#  '430': ['original', 'teens', 'teen', 'teen movie'],
#  '431': ['mafia', 'gangsters', 'gangster', 'organized crime'],
#  '432': ['sequel', 'sequels', 'good sequel', 'treasure hunt'],
#  '433': ['original', 'short-term memory loss', 'comedy', 'funny'],
#  '434': ['explosions', 'action packed', 'action', 'good action'],
#  '435': ['comedy', 'aliens', 'saturday night live', 'alien'],
#  '436': ['sexy', 'sex', 'sexual', 'erotic'],
#  '437': ['surveillance', 'saturday night live', 'chase', 'family'],
#  '438': ['good', 'goofy', 'new york city', 'fun movie'],
#  '439': ["so bad it's funny",
#   'israel',
#   'life philosophy',
#   'nudity (topless - notable)'],
#  '440': ['politics', 'world politics', 'secret service', 'president'],
#  '441': ['weed', 'marijuana', 'high school', 'teen'],
#  '442': ['action', 'good action', 'futuristic', 'future'],
#  '443': ['australia', 'good soundtrack', 'hawaii', 'surfing'],
#  '444': ['book', 'books', 'adapted from:book', 'based on a book'],
#  '445': ['silly', 'parody', 'spoof', 'comedy'],
#  '446': ['opera', 'foreign', 'revolution', 'china'],
#  '447': ['chick flick', 'fun movie', 'vampire human love', 'life philosophy'],
#  '448': ['existentialism', 'depression', 'death', 'life & death'],
#  '449': ['satire', 'funny', 'parody', 'hip hop'],
#  '450': ['life', 'touching', 'homeless', 'feel-good'],
#  '451': ['relationships', 'original', 'texas', 'nudity (topless - notable)'],
#  '452': ['costume drama', 'secrets', 'irish', 'irish accent'],
#  '453': ['romance', 'love story', 'romantic comedy', 'romantic'],
#  '454': ['adapted from:book', 'tom clancy', 'lawyer', 'lawyers'],
#  '455': ['animal movie', 'kids', 'family', 'kids and family'],
#  '456': ['crime', 'gangsters', 'chess', 'drugs'],
#  '457': ['action',
#   'based on a tv show',
#   'oscar (best supporting actor)',
#   'chase'],
#  '458': ['historical', 'history', 'indians', 'native americans'],
#  '459': ['action', 'betrayal', 'original', 'remake'],
#  '460': ['san francisco', 'childhood', 'heist', 'original'],
#  '461': ['queer', 'women', 'gay character', 'lesbian'],
#  '462': ['satirical', 'original', 'africa', 'farce'],
#  '463': ['original', 'lawyers', 'thriller', 'lawyer'],
#  '464': ['action packed', 'martial arts', 'good action', 'action'],
#  '465': ['war movie', 'vietnam war', 'innocence lost', 'war'],
#  '466': ['silly', 'spoof', 'comedy', 'parody'],
#  '467': ['strippers', 'sexual', 'women', 'nudity (topless - notable)'],
#  '468': ['whimsical', 'british', 'feel-good', 'england'],
#  '469': ['based on book',
#   'latin america',
#   'adapted from:book',
#   'based on a book'],
#  '470': ['disaster', 'great ending', 'original', 'hip hop'],
#  '471': ['original', 'whimsical', 'coen bros', 'coen brothers'],
#  '472': ['whimsical', 'dialogue', 'destiny', 'original'],
#  '473': ['stupid', 'idiotic', 'funny', 'comedy'],
#  '474': ['suspenseful', 'tense', 'assassin', 'secret service'],
#  '475': ['true story', 'based on true story', 'irish', 'corruption'],
#  '476': ['adolescence', 'teen movie', 'coming of age', 'coming-of-age'],
#  '477': ['biography', 'rock and roll', 'biographical', 'biopic'],
#  '478': ['original', 'satirical', 'vigilante', 'life philosophy'],
#  '479': ['good action', 'action', 'good', 'chase'],
#  '480': ['big budget', 'spielberg', 'special effects', 'dinosaurs'],
#  '481': ['violent', 'road trip', 'violence', 'serial killer'],
#  '482': ['violent', 'heist', 'violence', 'drugs'],
#  '483': ['depression', 'coming of age', 'criterion', '1930s'],
#  '484': ['kids', 'family', 'dog', 'dogs'],
#  '485': ['parody', 'good action', 'action', 'arnold'],
#  '486': ['comedy', 'kids', 'great', 'fun movie'],
#  '487': ['funny', 'comedy', 'western', 'good'],
#  '488': ['enigmatic', 'obsession', 'cross dressing', 'based on a play'],
#  '489': ['very funny', 'funny', 'original', 'comedy'],
#  '490': ['complex', 'twists & turns', 'thriller', 'nudity (rear)'],
#  '491': ['unlikely friendships', 'mentor', 'drama', 'friendship'],
#  '492': ['comedy', 'murder', 'mystery', 'murder mystery'],
#  '493': ['gangs', 'gangsters', 'violent', 'violence'],
#  '494': ['tense', 'action', 'good action', 'tom clancy'],
#  '495': ['erotic', 'male nudity', 'pornography', 'sexual'],
#  '496': ['relationships', 'innocence lost', 'character study', 'loneliness'],
#  '497': ['based on a play', 'witty', 'shakespeare', 'literature'],
#  '498': ['homeless', 'doctors', 'psychiatry', 'hospital'],
#  '499': ['original', 'relationships', 'romantic comedy', 'romantic'],
#  '500': ['family', 'divorce', 'children', 'comedy'],
#  '501': ['criterion', 'loneliness', 'bleak', 'social commentary'],
#  '502': ['teen movie', 'mentor', 'high school', 'martial arts'],
#  '503': ['melancholic', 'dark humor', 'los angeles', 'bleak'],
#  '504': ['prison', 'prison escape', 'futuristic', 'action'],
#  '505': ['family', 'children', 'stereotypes', 'original'],
#  '506': ['visually stunning',
#   '18th century',
#   'transgender',
#   'literary adaptation'],
#  '507': ['kidnapping', 'moral ambiguity', 'prison escape', 'road movie'],
#  '508': ['homophobia', 'homosexuality', 'gay', 'aids'],
#  '509': ['male nudity',
#   'amazing cinematography',
#   'passionate',
#   'oscar (best actress)'],
#  '510': ['gangs', 'original', 'justice', 'hip hop'],
#  '511': ['mentor', 'football', 'college', 'sports'],
#  '512': ['aliens', 'adapted from:book', 'based on a book', 'alien'],
#  '513': ['1930s', 'murder mystery', 'radio', 'highly quotable'],
#  '514': ['sarcasm', 'comedy', 'holiday', 'christmas'],
#  '515': ['costume drama',
#   'literary adaptation',
#   'melancholic',
#   'period piece'],
#  '516': ['comedy', 'feel good movie', 'military', 'feel-good'],
#  '517': ['based on a book', 'race issues', 'murder mystery', 'murder'],
#  '518': ['satirical', 'sexual', 'nudity (topless - notable)', 'humorous'],
#  '519': ['sequel', 'crappy sequel', 'franchise', 'cyborgs'],
#  '520': ['hilarious', 'spoof', 'parody', 'comedy'],
#  '521': ['mob', 'corruption', 'noir thriller', 'neo-noir'],
#  '522': ['brutal', 'brutality', 'violence', 'violent'],
#  '523': ['coming of age', 'intimate', 'coming-of-age', 'bittersweet'],
#  '524': ['true story', 'inspiring', 'sports', 'football'],
#  '525': ['depression', 'mental illness', 'original', 'homeless'],
#  '526': ['sexual', 'life', 'relationships', 'aids'],
#  '527': ['poland', 'oscar (best directing)', 'holocaust', 'jews'],
#  '528': ['original', 'sports', 'comedy', 'baseball'],
#  '529': ['based on true story', 'based on a true story', 'chess', 'mentor'],
#  '531': ['children', 'fairy tale', 'beautifully filmed', 'magic'],
#  '532': ['serial killer', 'dark comedy', 'black comedy', 'dark humor'],
#  '533': ['superheroes', 'dark hero', 'super hero', 'superhero'],
#  '534': ['beautifully filmed', 'c.s. lewis', 'love', 'love story'],
#  '535': ['los angeles',
#   'robert downey jr',
#   'ensemble cast',
#   'multiple storylines'],
#  '536': ['original', 'adapted from:book', 'touching', 'amy smart'],
#  '537': ['australia', 'pornography', 'erotic', 'sexual'],
#  '538': ['existentialism', 'talky', 'greed', 'based on a play'],
#  '539': ['love story', 'chick flick', 'romantic comedy', 'romantic'],
#  '540': ['sexual', 'sexy', 'erotic', 'voyeurism'],
#  '541': ['future', 'androids', 'futuristic', 'distopia'],
#  '542': ['very funny', 'original', 'comedy', 'funny'],
#  '543': ['very funny', 'hilarious', 'comedy', 'funny'],
#  '544': ['action', 'murder mystery', 'good action', 'chase'],
#  '545': ['grindhouse', 'original', 'loneliness', 'melancholic'],
#  '546': ['adapted from:game',
#   'video game adaptation',
#   'video game',
#   'based on a video game'],
#  '547': ['survival', 'wilderness', 'hunting', 'homeless'],
#  '548': ['fun movie', 'action packed', 'good action', 'action'],
#  '549': ['eccentricity', 'classical music', 'music', 'musicians'],
#  '550': ['relationships', 'gay character', 'sexual', 'gay'],
#  '551': ['animation', 'halloween', 'dark fantasy', 'stop motion'],
#  '552': ['adventure', 'fun movie', 'based on a book', 'swashbuckler'],
#  '553': ['vengeance', 'great acting', 'western', 'gunfight'],
#  '554': ['tense', 'courtroom', 'psychology', 'thriller'],
#  '555': ['ensemble cast', 'violence', 'violent', 'highly quotable'],
#  '556': ['president', 'documentary', 'political', 'politics'],
#  '558': ['animation', 'adventure', 'fantasy', 'books'],
#  '559': ['nudity (full frontal - notable)', 'pornography', 'erotic', 'sexual'],
#  '561': ['hitman', 'assassin', 'drama', 'stylish'],
#  '562': ['independent film', 'loneliness', 'bullying', 'adolescence'],
#  '563': ['revolution', 'social commentary', 'poverty', 'based on a book'],
#  '564': ['original', 'silly', 'male nudity', 'sexy'],
#  '565': ['immortality', 'horror', 'vampire', 'vampires'],
#  '566': ['great', 'original', 'writers', 'relationships'],
#  '568': ['women', 'england', 'indians', 'london'],
#  '569': ['kids', 'fun movie', 'sports', 'baseball'],
#  '570': ['melancholic', 'criterion', 'social commentary', 'independent film'],
#  '571': ['talky', 'original', 'relationships', 'drama'],
#  '573': ['childhood', 'foreign', 'children', 'teacher'],
#  '574': ['dysfunctional family',
#   'sexual',
#   'incest',
#   'mother-son relationship'],
#  '575': ['children', 'original', 'kids', 'childhood'],
#  '577': ['based on true story', 'animal movie', 'family', 'animals'],
#  '580': ['romantic', 'original', 'powerful ending', 'based on true story'],
#  '581': ['gay character', 'queer', 'gay', 'homosexuality'],
#  '582': ['oscar (best foreign language film)',
#   'latin america',
#   'french',
#   'foreign'],
#  '583': ['humorous', 'criterion', 'rome', 'talky'],
#  '585': ['spoof', 'original', 'parody', 'based on a tv show'],
#  '586': ['children', 'family', 'holiday', 'christmas'],
#  '587': ['romantic', 'supernatural', 'love story', 'ghosts'],
#  '588': ['fairy tale',
#   'animation',
#   'disney animated feature',
#   'kids and family'],
#  '589': ['arnold', 'action', 'cyborgs', 'future'],
#  '590': ['oscar (best picture)',
#   'oscar (best cinematography)',
#   'indians',
#   'native americans'],
#  '592': ['super-hero', 'dark hero', 'vigilante', 'super hero'],
#  '593': ['oscar (best picture)',
#   'suspenseful',
#   'serial killer',
#   'oscar (best directing)'],
#  '594': ['cartoon', 'fairy tale', 'animation', 'disney animated feature'],
#  '595': ['kids and family',
#   'disney animated feature',
#   'animation',
#   'fairy tale'],
#  '596': ['animated', 'cartoon', 'disney animated feature', 'animation'],
#  '597': ['girlie movie', 'chick flick', 'romantic', 'romantic comedy'],
#  '598': ['foreign', 'russia', 'criterion', 'russian'],
#  '599': ['violent', 'western', 'violence', 'gunfight'],
#  '600': ['original', 'texas', 'road movie', 'gangsters'],
#  '601': ['harsh', 'spanish', 'surveillance', 'china'],
#  '602': ['documentary', 'art', 'musicians', 'jazz'],
#  '603': ['original', 'divorce', 'single father', 'parenthood'],
#  '605': ['sweet', 'romantic', 'single father', 'romantic comedy'],
#  '606': ['original', 'horror', 'sequels', 'good sequel'],
#  '608': ['crime', 'imdb top 250', 'dark humor', 'coen bros'],
#  '609': ['sequel', 'talking animals', 'dogs', 'dog'],
#  '610': ['dark fantasy', 'adapted from:comic', 'sci-fi', 'animation'],
#  '611': ['demons', 'splatter', 'franchise', 'horror'],
#  '612': ['romantic', 'unlikely friendships', 'original', 'good soundtrack'],
#  '613': ['adaptation', 'literature', 'based on a book', 'adapted from:book'],
#  '614': ['original', 'goretastic', 'very interesting', 'life philosophy'],
#  '615': ['golden palm', 'criterion', 'bittersweet', 'foreign'],
#  '616': ['animals', 'cartoon', 'disney animated feature', 'animation'],
#  '617': ['reflective', 'relationships', 'spanish', 'almodovar'],
#  '618': ['screwball', 'art', 'comedy', 'screwball comedy'],
#  '619': ['monkey', 'original', 'baseball', 'sports'],
#  '621': ['intimate', 'complex', 'relationships', 'dysfunctional family'],
#  '624': ['free to download', 'brutality', 'finnish', 'prison'],
#  '626': ['original', 'comedy', 'sexy', 'women'],
#  '627': ['political', 'dark humor', 'powerful ending', 'black comedy'],
#  '628': ['lawyers', 'courtroom', 'lawyer', 'surprise ending'],
#  '630': ['pornography',
#   'nudity (full frontal)',
#   'nudity (full frontal - notable)',
#   'sexual'],
#  '631': ['talking animals', 'animation', 'sequels', 'sequel'],
#  '632': ['war movie', 'criterion', 'drama', 'wartime'],
#  '633': ['solitude', 'unlikely friendships', 'original', 'friendship'],
#  '634': ['stupid', 'futuristic', 'horrible', 'dinosaurs'],
#  '635': ['touching', 'small town', 'race', 'adoption'],
#  '637': ['series', 'based on a tv show', 'comedy', 'original'],
#  '638': ['romantic', 'romantic comedy', 'chick flick', 'single father'],
#  '639': ['sexy', 'sex', 'pornography', 'sexual'],
#  '640': ['sexy', 'thriller', 'original', 'remake'],
#  '641': ["so bad it's funny", 'comedy', 'indians', 'jungle'],
#  '645': ['talky', 'intimate', 'passionate', 'criterion'],
#  '647': ['war', 'courage', 'military', 'gulf war'],
#  '648': ['spy', 'action', 'espionage', 'spying'],
#  '649': ['literary adaptation', 'tokyo', 'unusual plot structure', 'japan'],
#  '650': ['literature', '18th century', 'adapted from:book', 'based on a book'],
#  '651': ['predictable', 'good', 'sexualized violence', 'original'],
#  '652': ['pornography', 'original', 'weird', 'cooking'],
#  '653': ['mythology', 'medieval', 'fantasy', 'dragons'],
#  '656': ['new jersey', 'comedy', 'sports', 'basketball'],
#  '658': ['fun movie', 'australian', 'music', 'musical'],
#  '659': ['enigmatic', 'based on a book', 'adapted from:book', 'criterion'],
#  '660': ['life & death', 'original', 'life', 'author:neil gaiman'],
#  '661': ['stop-motion', 'adapted from:book', 'based on book', 'stop motion'],
#  '662': ['suspense', 'teen movie', 'thriller', 'father daughter relationship'],
#  '663': ['drugs', 'comedy', 'awesome soundtrack', 'weird'],
#  '664': ['dialogue', 'mentor', 'original', 'pornography'],
#  '665': ['allegory', 'masterpiece', 'surrealism', 'surreal'],
#  '666': ['weird', 'swedish', 'exceptional acting', 'mentor'],
#  '667': ['fighting', 'sequels', 'fight scenes', 'martial arts'],
#  '668': ['masterpiece', 'poverty', 'criterion', 'india'],
#  '670': ['lyrical', 'trilogy', 'criterion', 'poignant'],
#  '671': ['spoof', 'sci-fi', 'hilarious', 'sarcasm'],
#  '673': ['basketball', 'sports', 'animation', 'cartoon'],
#  '674': ['sci fi', 'sexy', 'sci-fi', 'cult film'],
#  '678': ['oscar (best directing)', 'original', 'too short', 'short'],
#  '679': ['coming of age', 'visually appealing', 'ireland', 'irish'],
#  '680': ['enigmatic', 'dystopia', 'futuristic', 'criterion'],
#  '681': ['enigmatic', 'criterion', 'cynical', 'pornography'],
#  '682': ['classic car', 'indians', 'life philosophy', 'finnish'],
#  '685': ['friendship', 'relationships', 'aids', 'gay'],
#  '687': ['original', 'australian', 'pornography', 'australia'],
#  '688': ['war', 'family', 'feel-good', 'kids and family'],
#  '690': ['drama', 'germany', 'berlin', 'german'],
#  '691': ['romance', 'chick flick', 'romantic comedy', 'romantic'],
#  '692': ['good action', 'androids', 'action', 'cyborgs'],
#  '694': ['realistic action', 'high school', 'good action', 'action'],
#  '695': ['police investigation', 'murder', 'sexy', 'serial killer'],
#  '696': ['disturbing',
#   'nudity (full frontal)',
#   'lesbian',
#   'nudity (full frontal - notable)'],
#  '697': ['sexualized violence', 'twists & turns', 'quirky', 'original'],
#  '698': ['nudity (full frontal)',
#   'erotic',
#   'nudity (full frontal - notable)',
#   'sexual'],
#  '700': ['bullying', 'high school', 'teen movie', 'teen'],
#  '701': ['poland', 'harsh', 'melancholic', 'intimate'],
#  '702': ['intimate', 'bleak', 'talky', 'criterion'],
#  '703': ['destiny', 'surreal', 'original', 'visually appealing'],
#  '704': ['kung fu', 'fighting', 'fight scenes', 'martial arts'],
#  '705': ['humorous', 'original', 'mozart', 'mental illness'],
#  '706': ['fun movie', 'grindhouse', 'sports', 'basketball'],
#  '707': ['police corruption', 'detective', 'corruption', 'neo-noir'],
#  '708': ['good romantic comedies',
#   'chick flick',
#   'romantic comedy',
#   'romantic'],
#  '709': ['dog', 'animation', 'talking animals', 'disney animated feature'],
#  '710': ['comedy', 'boston', 'sports', 'basketball'],
#  '711': ['fun', 'animals', 'original', 'family'],
#  '712': ['obsession', 'romance', 'passionate', 'prison'],
#  '713': ['based on book', 'based on a book', 'latin america', 'spanish'],
#  '714': ['weird', 'western', 'surreal', 'life & death'],
#  '715': ['france', 'beautiful scenery', 'scenic', 'cinematography'],
#  '716': ['bullying', 'original', 'gangs', 'race issues'],
#  '717': ['screwball', 'farce', 'spanish', 'almodovar'],
#  '718': ['medieval', 'comedy', 'france', 'french'],
#  '719': ['funny', 'comedy', 'clones', 'cloning'],
#  '720': ['british comedy', 'cool', 'claymation', 'funny'],
#  '722': ['movie business', 'criterion', 'documentary', 'pornography'],
#  '724': ['witch', 'goth', 'teen movie', 'teen'],
#  '725': ['comedy', 'satire', 'sports', 'satirical'],
#  '726': ['lawyers', 'lawyer', 'death penalty', 'death'],
#  '728': ['british comedy', 'based on a book', 'adapted from:book', '1930s'],
#  '729': ['enigmatic', 'weird', 'dreamlike', 'surreal'],
#  '731': ['detective', 'hit men', 'nudity (topless - notable)', 'new orleans'],
#  '732': ['vigilante', 'fight scenes', 'grindhouse', 'gangs'],
#  '733': ['alcatraz', 'action packed', 'action', 'good action'],
#  '734': ['off-beat comedy', 'very funny', 'vigilantism', 'comedy'],
#  '735': ['zombies', 'dark hero', 'splatter', 'dark humor'],
#  '736': ['chase', 'big budget', 'special effects', 'natural disaster'],
#  '737': ['nudity (topless)', 'futuristic', 'based on a comic', 'cyberpunk'],
#  '741': ['complex', 'futuristic', 'cyberpunk', 'cyborgs'],
#  '742': ['books', 'adapted from:book', 'horror', 'based on a book'],
#  '743': ['spy', 'funny as hell', 'spoof', 'parody'],
#  '745': ['animated', 'aardman', 'animation', 'claymation'],
#  '746': ['mob', 'film noir', 'noir', 'organized crime'],
#  '747': ["so bad it's funny", 'idiotic', 'stupidity', 'stupid'],
#  '748': ['conspiracy', 'aliens', 'alien', 'alien invasion'],
#  '750': ['cold war', 'nuclear war', 'imdb top 250', 'kubrick'],
#  '751': ['talky', 'dreamlike', 'surreal', 'surrealism'],
#  '753': ['beautiful scenery', 'original', 'romantic', 'romance'],
#  '754': ['family', 'unlikely friendships', 'adventure', 'small town'],
#  '755': ['indians', 'adapted from:book', 'adventure', 'literary adaptation'],
#  '756': ['pornography', 'life philosophy', 'documentary', 'obsession'],
#  '757': ['melancholic', 'stylized', 'meditative', 'wuxia'],
#  '759': ['intimate', 'mentor', 'original', 'documentary'],
#  '760': ['german', 'wwii', 'germany', 'world war ii'],
#  '761': ['superheroes', 'super hero', 'superhero', 'based on a comic'],
#  '762': ['nudity (topless - notable)',
#   'adapted from:book',
#   'based on a book',
#   'strippers'],
#  '763': ['coming-of-age', 'ireland', 'irish accent', 'irish'],
#  '764': ['melancholic', 'independent film', 'loneliness', 'liv tyler'],
#  '765': ['comedy', 'doctors', 'childhood', 'drama'],
#  '766': ['very interesting', 'transgender', 'obsession', 'true story'],
#  '771': ['male nudity',
#   'oscar (best foreign language film)',
#   'music',
#   'criterion'],
#  '775': ['art house', 'macabre', 'criterion', 'surreal'],
#  '776': ['sexy', 'original', 'women', 'intense'],
#  '778': ['addiction', 'drugs', 'drug addiction', 'drug abuse'],
#  '779': ['romance', 'romantic comedy', 'romantic', 'destiny'],
#  '780': ['big budget', 'aliens', 'alien invasion', 'alien'],
#  '781': ['visually appealing',
#   'relationships',
#   'liv tyler',
#   'nudity (topless - notable)'],
#  '782': ['oscar (best supporting actor)', 'obsession', 'baseball', 'sports'],
#  '783': ['cartoon',
#   'adapted from:book',
#   'animation',
#   'disney animated feature'],
#  '784': ['hilarious', 'dark comedy', 'comedy', 'goofy'],
#  '785': ['goofy', 'funniest movies', 'bowling', 'comedy'],
#  '786': ['weapons', 'good action', 'action', 'arnold'],
#  '787': ['bollywood', 'china', 'criterion', 'solitude'],
#  '788': ['hilarious', 'buddy movie', 'goofy', 'comedy'],
#  '789': ['lesbian', 'pornography', 'women', 'spanish'],
#  '790': ['gypsy accent', 'bollywood', 'cinematography', 'culture clash'],
#  '791': ['music', 'holocaust', 'poland', 'musicians'],
#  '792': ['melancholic', 'tokyo', 'mozart', 'visually appealing'],
#  '793': ['intimate', 'spanish', 'criterion', 'melancholic'],
#  '794': ['original', 'glbt', 'working class', 'gay'],
#  '797': ['criterion', 'gay', 'male nudity', 'pornography'],
#  '798': ['special effects', 'big budget', 'action', 'disaster'],
#  '799': ['frightening', 'horror', 'ghosts', 'supernatural'],
#  '800': ['texas', 'complex', 'southern theme', 'small town'],
#  '801': ['spy', 'kids', 'kids and family', 'spying'],
#  '802': ['love story', 'sentimental', 'small town', 'tear jerker'],
#  '803': ['dialogue driven',
#   'friendship',
#   'unlikely friendships',
#   'relationships'],
#  '804': ['dialogue', 'dialogue driven', 'relationships', 'ethnic conflict'],
#  '805': ['lawyer', 'lawyers', 'vigilantism', 'vigilante'],
#  '806': ['talky', 'great acting', 'dialogue', 'based on a play'],
#  '807': ['love', 'criterion', 'paris', 'relationships'],
#  '808': ['wilderness', 'single father', 'alaska', 'kids and family'],
#  '809': ['nudity (topless - brief)', 'chase', 'good action', 'action'],
#  '810': ['special effects', "so bad it's funny", 'bad plot', 'horrible'],
#  '813': ['road movie', 'funny', 'original', 'comedy'],
#  '816': ['judaism', 'enigmatic', 'dialogue driven', 'original'],
#  '818': ['original', 'sequel', 'good sequel', 'sequels'],
#  '819': ['parallel universe', 'visually appealing', 'spanish', 'weird'],
#  '820': ['jungle', 'melancholic', 'spanish', 'criterion'],
#  '821': ['cheating', 'great', 'transformation', 'nocturnal'],
#  '823': ['sexy', 'intellectual', 'art', 'criterion'],
#  '824': ['original', 'germany', '18th century', 'fascism'],
#  '827': ['original',
#   'pornography',
#   'nudity (topless - notable)',
# ...
#   'criterion',
#   'japan'],
#  '856': ['gypsy accent', 'talky', 'off-beat comedy', 'rome'],
#  '858': ['masterpiece', 'mafia', 'organized crime', 'francis ford copolla'],
#  '860': ['german', 'queer', 'gay', 'gay character'],
#  '861': ['police', 'kung fu', 'martial arts', 'fight scenes'],
#  '862': ['women', 'runaway', 'sisters', 'kidnapping'],
#  '864': ['loneliness', 'complex', 'talky', 'male nudity'],
#  '865': ['violent', 'violence', 'brutal', 'gangs'],
#  '866': ['neo-noir', 'stylish', 'mob', 'tense'],
#  '867': ['predictable', "so bad it's funny", 'silly', 'arnold'],
#  '868': ['melancholic', 'cult classic', 'australia', 'australian'],
#  '869': ['political corruption', 'jazz', 'musicians', 'music'],
#  '870': ['original', "so bad it's funny", 'horrible', 'comedy'],
#  '871': ['gay character', 'romantic', 'brutality', "so bad it's funny"],
#  '872': ['art house', 'meditative', 'criterion', 'loneliness'],
#  '874': ['death penalty', 'fight scenes', 'life philosophy', 'prison'],
#  '875': ['good action', 'revenge', 'fight scenes', 'action'],
#  '876': ['original', 'action', 'fight scenes', 'hong kong'],
#  '877': ['teen', 'teen movie', 'high school', 'women'],
#  '879': ['monster', 'adapted from:book', 'monsters', 'based on book'],
#  '880': ['pointless', 'adapted from:book', 'mad scientist', 'based on a book'],
#  '881': ['fun movie', 'kids', 'president', 'secret service'],
#  '882': ['bad ending', 'pointless', 'very interesting', 'original'],
#  '884': ['drug abuse', 'drinking', 'addiction', 'drugs'],
#  '885': ['original', 'fantasy', 'imaginary friend', 'childhood'],
#  '886': ['comedy', 'good action', 'action', 'undercover cop'],
#  '888': ['adventure', 'great', 'dinosaurs', 'franchise'],
#  '889': ['classic car', 'obsession', 'erotic', 'intimate'],
#  '891': ['serial killer', 'halloween', 'slasher', 'franchise'],
#  '892': ['mistaken identity',
#   'shakespeare',
#   'cross dressing',
#   'based on a play'],
#  '893': ['wartime', 'nazis', 'adapted from:book', 'world war ii'],
#  '895': ['mentor', 'parallel universe', 'metaphysics', 'women'],
#  '896': ['france', 'sexual', 'gay character', 'adolescence'],
#  '897': ['romance',
#   'oscar (best supporting actress)',
#   'adapted from:book',
#   'oscar (best actress)'],
#  '898': ['classic', 'oscar (best actor)', 'screwball comedy', 'imdb top 250'],
#  '899': ['afi 100', 'imdb top 250', 'dance', 'musical'],
#  '900': ['dancing',
#   'oscar (best cinematography)',
#   'paris',
#   'oscar (best picture)'],
#  '901': ['fashion', 'musical', 'paris', 'dancing'],
#  '902': ['adapted from:book', 'love story', 'bittersweet', 'romantic'],
#  '903': ['enigmatic', 'imdb top 250', 'obsession', 'hitchcock'],
#  '904': ['imdb top 250', 'suspenseful', 'voyeurism', 'hitchcock'],
#  '905': ['screwball comedy',
#   'imdb top 250',
#   'oscar (best directing)',
#   'oscar (best picture)'],
#  '906': ['thriller', 'murder', 'tense', 'oscar (best actress)'],
#  '907': ['mistaken identity', 'divorce', 'dance', 'dancing'],
#  '908': ['suspense', 'mistaken identity', 'hitchcock', 'imdb top 250'],
#  '909': ['loneliness',
#   'oscar (best directing)',
#   'oscar (best picture)',
#   'imdb top 250'],
#  '910': ['comedy', 'screwball comedy', 'cross dressing', 'imdb top 250'],
#  '911': ['twists & turns', 'paris', 'hitchcock', 'criterion'],
#  '912': ['classic', 'imdb top 250', 'oscar (best picture)', 'world war ii'],
#  '913': ['imdb top 250',
#   'private detective',
#   'highly quotable',
#   'noir thriller'],
#  '914': ['70mm',
#   'based on a play',
#   'oscar (best picture)',
#   'oscar (best supporting actor)'],
#  '915': ['classic', 'romantic comedy', 'romance', 'paris'],
#  '916': ['romantic comedy', 'imdb top 250', 'oscar (best actress)', 'rome'],
#  '917': ['classic', 'childhood', 'based on a book', 'boarding school'],
#  '918': ['family', 'classic', 'good music', 'musical'],
#  '919': ['imdb top 250', 'classic', 'witch', 'witches'],
#  '920': ['oscar (best supporting actress)',
#   'oscar (best cinematography)',
#   'civil war',
#   'oscar (best directing)'],
#  '921': ['original', 'television', 'based on a tv show', 'comedy'],
#  '922': ['hollywood', 'imdb top 250', 'talky', 'narrated'],
#  '923': ['afi 100', 'enigmatic', 'masterpiece', 'imdb top 250'],
#  '924': ['visual', 'masterpiece', 'space', 'space travel'],
#  '925': ['poland', 'germany', 'world war ii', 'nazis'],
#  '926': ['oscar (best picture)',
#   'afi 100',
#   'imdb top 250',
#   'oscar (best directing)'],
#  '927': ['divorce', 'chick flick', 'classic', 'women'],
#  '928': ['criterion',
#   'oscar (best picture)',
#   'hitchcock',
#   'oscar (best cinematography)'],
#  '929': ['criterion', 'espionage', 'hitchcock', 'assassination'],
#  '930': ['imdb top 250', 'spying', 'espionage', 'hitchcock'],
#  '931': ['amnesia', 'criterion', 'psychiatry', 'hitchcock'],
#  '932': ['classic', 'romance', 'romantic', 'love story'],
#  '933': ['amazing cinematography',
#   'chase',
#   'oscar (best cinematography)',
#   'hitchcock'],
#  '934': ['sweet', 'family', 'wedding', 'comedy'],
#  '935': ['dance', 'musical', 'dancing', 'music'],
#  '936': ['satire', 'cold war', 'russia', 'paris'],
#  '937': ['paris', 'romantic comedy', 'romance', 'romantic'],
#  '938': ['oscar (best cinematography)',
#   'music',
#   'musical',
#   'oscar (best directing)'],
#  '939': ['original', 'great ending', 'mistaken identity', 'comedy'],
#  '940': ['oscar (best editing)', 'imdb top 250', 'classic', 'swashbuckler'],
#  '941': ['adventure', 'sword fighting', 'swashbuckler', 'sword fight'],
#  '942': ['mystery',
#   'detective',
#   'oscar (best cinematography)',
#   'murder mystery'],
#  '943': ['oscar (best cinematography)', 'romantic', 'romance', 'ghosts'],
#  '944': ['destiny', '1930s', 'utopia', 'adapted from:book'],
#  '945': ['musical', 'dance', 'dancing', 'mistaken identity'],
#  '946': ['wartime', 'nazis', 'world war ii', 'poland'],
#  '947': ['classic', 'criterion', 'screwball', 'screwball comedy'],
#  '948': ['epic', 'oscar (best directing)', 'long', 'oscar (best picture)'],
#  '949': ['complex characters',
#   'adapted from:book',
#   'based on a book',
#   'oscar (best supporting actress)'],
#  '950': ['police investigation', 'mystery', 'detective', 'murder mystery'],
#  '951': ['talky', 'classic', 'screwball comedy', 'screwball'],
#  '952': ['oscar (best directing)',
#   'oscar (best picture)',
#   'oscar (best cinematography)',
#   '70mm'],
#  '953': ['heartwarming', 'small town', 'classic', 'imdb top 250'],
#  '954': ['idealism', 'politics', 'political corruption', 'political'],
#  '955': ['comedy', 'imdb top 250', 'screwball comedy', 'screwball'],
#  '956': ['parenthood', 'sentimental', 'screwball comedy', 'adoption'],
#  '957': ['based on a book',
#   'literary adaptation',
#   'silent',
#   'unusual plot structure'],
#  '958': ['women', 'police investigation', 'murder mystery', 'screwball'],
#  '959': ['talky', 'oscar (best actress)', 'obsession', 'adapted from:book'],
#  '960': ['fantasy', 'devil', 'psychiatry', 'gangsters'],
#  '961': ['childhood',
#   'literary adaptation',
#   'unusual plot structure',
#   'england'],
#  '962': ['drinking', 'runaway', 'original', 'criterion'],
#  '963': ['drinking', 'original', 'mistaken identity', 'small town'],
#  '964': ['runaway', 'gunfight', 'chase', 'western'],
#  '965': ['espionage', 'spy', 'criterion', 'hitchcock'],
#  '966': ['war', 'wwii', 'best war films', 'world war ii'],
#  '967': ['pornography', 'criterion', 'gunfight', 'western'],
#  '968': ['splatter', 'horror', 'creepy', 'zombies'],
#  '969': ['classic', 'imdb top 250', 'adventure', 'africa'],
#  '970': ['humorous', 'caper', 'criterion', 'off-beat comedy'],
#  '971': ['censorship',
#   'talky',
#   'based on a play',
#   'oscar (best supporting actor)'],
#  '972': ['drama', 'romantic', 'paris', 'adultery'],
#  '973': ['political', 'greed', 'imdb top 250', 'idealism'],
#  '974': ['cinematography', 'french', 'criterion', 'france'],
#  '976': ['love story', 'war', 'wartime', 'adapted from:book'],
#  '980': ['kung fu', 'fight scenes', 'martial arts', 'action'],
#  '981': ['south africa', 'original', 'bad plot', 'chase'],
#  '982': ['intimate', 'sexy', 'drinking', 'small town'],
#  '984': ['life philosophy', 'original', 'finnish', 'relationships'],
#  '985': ['spelling bee', 'graphic design', 'documentary', 'tragedy'],
#  '986': ['beautifully filmed',
#   'oscar (best cinematography)',
#   'amazing photography',
#   'father daughter relationship'],
#  '987': ['sexy', 'sexuality', 'pornography', 'sexual'],
#  '988': ['great music', 'rock and roll', 'music', 'music business'],
#  '989': ['adapted from:book',
#   'pornography',
#   'based on a book',
#   'based on book'],
#  '990': ['chase', 'good action', 'fight scenes', 'action'],
#  '991': ['historical', 'ireland', 'irish', 'irish accent'],
#  '992': ['twists & turns', 'twist ending', 'cheating', 'murder mystery'],
#  '993': ['true story', 'mentor', 'based on a book', 'books'],
#  '994': ['new jersey', 'food', 'brothers', 'cooking'],
#  '996': ['remake', 'action', 'gangs', 'gunfight'],
#  '997': ['greed', 'adultery', 'betrayal', 'noir thriller'],
#  '998': ['chick flick', 'bank robbery', 'stereotypes', 'women'],
#  '999': ['crime', 'nudity (topless - notable)', 'ensemble cast', 'hit men'],
#  '1000': ['stylish', 'serial killer', 'obsession', 'murder'],
#  '1002': ['new york', 'indie', 'solitude', 'grindhouse'],
#  '1003': ['doctors', 'conspiracy', 'thriller', 'homeless'],
#  '1004': ['action packed', 'fight scenes', 'action', 'good action'],
#  '1005': ['mentor', 'olympics', 'underdog', 'sports'],
#  '1006': ['lawyer', 'book', 'based on a book', 'adapted from:book'],
#  '1007': ['fun movie', 'children', 'disney', 'family'],
#  '1008': ['us history', 'historical', 'history', 'indians'],
#  '1009': ['disney', 'witch', 'kids', 'children'],
#  '1010': ['disney', 'kids and family', 'cars', 'racing'],
#  '1011': ['good sequel', 'sequels', 'sequel', 'racing'],
#  '1012': ['family', 'classic', 'dogs', 'dog'],
#  '1013': ['divorce', 'children', 'family', 'switching places'],
#  '1014': ['family', 'disney', 'sweet', 'small town'],
#  '1015': ['family', 'animal movie', 'talking animals', 'animals'],
#  '1016': ['dogs', 'children', 'family', 'dog'],
#  '1017': ['based on a book', 'family', 'adventure', 'island'],
#  '1018': ['dog', 'fun movie', 'disney', 'family'],
#  '1019': ['based on a book', 'submarine', 'adventure', 'adapted from:book'],
#  '1020': ['feel good movie', 'feel-good', 'sports', 'olympics'],
#  '1021': ['kids', 'baseball', 'family', 'sports'],
#  '1022': ['animated', 'fairy tale', 'animation', 'disney animated feature'],
#  '1023': ['adapted from:book', 'disney', 'animation', 'cartoon'],
#  '1024': ['animation', 'disney animated feature', 'latin america', 'cartoon'],
#  '1025': ['animated', 'cartoon', 'animation', 'disney animated feature'],
#  '1026': ['simple', 'animation', 'disney', 'cartoon'],
#  '1027': ['good', 'sword fight', 'medieval', 'adventure'],
#  '1028': ['family', 'musical', 'children', 'childhood'],
#  '1029': ['animals', 'cartoon', 'disney animated feature', 'animation'],
#  '1030': ['musical', 'disney', 'dragons', 'animation'],
#  '1031': ['london', 'witch', 'magic', 'children'],
#  '1032': ['adapted from:book',
#   'disney animated feature',
#   'animation',
#   'cartoon'],
#  '1033': ['friendship',
#   'unlikely friendships',
#   'animation',
#   'disney animated feature'],
#  '1034': ['dark humor', 'violent', 'california', 'serial killer'],
#  '1035': ['musical', 'children', 'oscar (best picture)', 'music'],
#  '1036': ['action packed', 'lone hero', 'action', 'good action'],
#  '1037': ['special effects', 'technology', 'virtual reality', 'futuristic'],
#  '1038': ['relationships', 'loneliness', 'bittersweet', 'original'],
#  '1039': ['family', 'weird', 'original', 'highly quotable'],
#  '1040': ['spying', 'spy', 'london', 'surveillance'],
#  '1041': ['race issues', 'family drama', 'secrets', 'adoption'],
#  '1042': ['nostalgic', 'rock and roll', 'musicians', 'music business'],
#  '1043': ['original', 'relationships', 'based on a play', 'nudity (rear)'],
#  '1044': ['nudity (topless - notable)', 'art', 'artist', 'biographical'],
#  '1045': ['farce', 'original', 'life philosophy', 'virginity'],
#  '1046': ['homosexuality', 'gay character', 'glbt', 'gay'],
#  '1047': ['action packed', 'action', 'assassin', 'good action'],
#  '1049': ['true story', 'irish accent', 'africa', 'lions'],
#  '1050': ['original', 'based on a play', 'great acting', 'shakespeare'],
#  '1051': ['drugs', 'drinking', 'independent film', 'loneliness'],
#  '1053': ['pornography', 'sexy', 'obsession', 'nudity (topless - notable)'],
#  '1054': ['race issues', 'racism', 'stereotypes', 'segregation'],
#  '1055': ['president', 'chase', 'conspiracy', 'secret service'],
#  '1056': ['nudity (full frontal - notable)',
#   'based on a book',
#   'literary adaptation',
#   'love story'],
#  '1057': ['great music', 'good music', 'music', 'musical'],
#  '1058': ['capitalism', 'cuba', 'foreign', 'latin america'],
#  '1059': ['romantic', 'love story', 'shakespeare', 'love'],
#  '1060': ['independent film', 'relationships', 'friendship', 'great dialogue'],
#  '1061': ['child abuse', 'vengeance', 'sexual abuse', 'innocence lost'],
#  '1062': ['cancer', 'mentor', 'hospital', 'road movie'],
#  '1063': ['independent film', 'prostitution', 'homeless', 'male nudity'],
#  '1064': ['disney', 'sequel', 'sequels', 'good sequel'],
#  '1066': ['musical', 'dancing', 'dance', 'spelling bee'],
#  '1067': ['mistaken identity', 'musical', 'dancing', 'dance'],
#  '1068': ['tense', 'police investigation', 'noir thriller', 'anti-semitism'],
#  '1069': ['murder mystery', 'noir', 'private detective', 'noir thriller'],
#  '1070': ['vampire human love', 'film noir', 'original', 'light'],
#  '1071': ['relationships', 'culture clash', 'gay character', 'infidelity'],
#  '1073': ['adapted from:book', 'children', 'chocolate', 'imagination'],
#  '1075': ['childhood', 'pornography', 'life philosophy', 'sexual'],
#  '1076': ['criterion', 'ghosts', 'eerie', 'creepy'],
#  '1077': ['social commentary', 'comedy', 'futuristic', 'future'],
#  '1078': ['satirical', 'political', 'comedy', 'world politics'],
#  '1079': ['absurd',
#   'oscar (best supporting actor)',
#   'comedy',
#   'british comedy'],
#  '1080': ['comedy', 'monty python', 'british comedy', 'jesus'],
#  '1081': ['music', 'transgender', 'glbt', 'cross dressing'],
#  '1082': ['corruption', 'political', 'politics', 'world politics'],
#  '1083': ['great movie', 'great', 'comedy', '70mm'],
#  '1084': ['violence',
#   'imdb top 250',
#   'violent',
#   'oscar (best cinematography)'],
#  '1085': ['adapted from:book', 'fish', 'narrated', 'based on a book'],
#  '1086': ['murder', 'talky', 'police investigation', 'hitchcock'],
#  '1087': ['catholicism', 'unusual plot structure', 'dramatic', 'opera'],
#  '1088': ['love story', 'dancing', 'dance', 'girlie movie'],
#  '1089': ['violent', 'hit men', 'violence', 'undercover cop'],
#  '1090': ['war movie', 'war', 'vietnam war', 'best war films'],
#  '1091': ['dumb but funny', 'goofy', 'comedy', 'silly fun'],
#  '1092': ['sexy', 'sex', 'sexual', 'erotic'],
#  '1093': ['biography', 'drug abuse', 'biopic', 'rock and roll'],
#  '1094': ['oscar (best writing - screenplay written directly for the screen)',
#   'twist',
#   'secrets',
#   'twists & turns'],
#  '1095': ['ensemble cast',
#   'greed',
#   'oscar (best supporting actor)',
#   'dialogue driven'],
#  '1096': ['poland', 'heartbreaking', 'holocaust', 'oscar (best actress)'],
#  '1097': ['aliens', 'spielberg', 'alien', 'children'],
#  '1098': ['dialogue', 'original', 'ensemble cast', 'independent film'],
#  '1099': ['based on a book', 'ghosts', 'holiday', 'christmas'],
#  '1100': ['sports', 'cars', 'race', 'racing'],
#  '1101': ['cool', 'aviation', 'action', 'love story'],
#  '1102': ['quirky', 'grindhouse', 'hit men', 'off-beat comedy'],
#  '1103': ['loneliness', 'adolescence', 'rebellion', 'teenager'],
#  '1104': ['exceptional acting',
#   'oscar (best supporting actress)',
#   'oscar (best actress)',
#   'imdb top 250'],
#  '1105': ['franchise', 'original', 'slasher', 'teens'],
#  '1107': ['women', 'fun movie', 'original', 'funny'],
#  '1111': ['documentary',
#   'narrated',
#   'amazing cinematography',
#   'beautifully filmed'],
#  '1112': ['quirky', 'original', 'new jersey', 'heist'],
#  '1113': ['queer', 'women', 'cross dressing', 'internet'],
#  '1114': ['mob', 'gangster', 'gangsters', 'mafia'],
#  '1116': ['intimate',
#   'nudity (full frontal - notable)',
#   'workplace',
#   'melancholic'],
#  ...}
